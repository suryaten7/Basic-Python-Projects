# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1*np.arange(1000)) #+ np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (990, 10, 1) Y.shape (990,)

# %%
### try autoregressive RNN model
i = Input(shape=(T, 1))
x = SimpleRNN(15, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.001),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Epoch 1/80
# 16/16 [==============================] - 0s 21ms/step - loss: 0.9442 - val_loss: 0.5927
# Epoch 2/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4319 - val_loss: 0.2996
# Epoch 3/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2214 - val_loss: 0.1482
# Epoch 4/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1041 - val_loss: 0.0616
# Epoch 5/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0420 - val_loss: 0.0251
# Epoch 6/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0200 - val_loss: 0.0161
# Epoch 7/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0145 - val_loss: 0.0126
# Epoch 8/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0080
# Epoch 9/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 10/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 11/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 12/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 13/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 14/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 15/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 16/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 17/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 18/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 19/80
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 20/80
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 21/80
# 16/16 [==============================] - 0s 10ms/step - loss: 9.6258e-04 - val_loss: 8.1866e-04
# Epoch 22/80
# 16/16 [==============================] - 0s 10ms/step - loss: 7.7396e-04 - val_loss: 6.6075e-04
# Epoch 23/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.0171e-04 - val_loss: 4.8476e-04
# Epoch 24/80
# 16/16 [==============================] - 0s 10ms/step - loss: 4.5582e-04 - val_loss: 3.8157e-04
# Epoch 25/80
# 16/16 [==============================] - 0s 10ms/step - loss: 3.5400e-04 - val_loss: 3.1060e-04
# Epoch 26/80
# 16/16 [==============================] - 0s 10ms/step - loss: 2.8319e-04 - val_loss: 2.4983e-04
# Epoch 27/80
# 16/16 [==============================] - 0s 10ms/step - loss: 2.3100e-04 - val_loss: 1.9864e-04
# Epoch 28/80
# 16/16 [==============================] - 0s 11ms/step - loss: 1.8836e-04 - val_loss: 1.6619e-04
# Epoch 29/80
# 16/16 [==============================] - 0s 11ms/step - loss: 1.5762e-04 - val_loss: 1.4505e-04
# Epoch 30/80
# 16/16 [==============================] - 0s 10ms/step - loss: 1.4163e-04 - val_loss: 1.2865e-04
# Epoch 31/80
# 16/16 [==============================] - 0s 10ms/step - loss: 1.2853e-04 - val_loss: 1.2049e-04
# Epoch 32/80
# 16/16 [==============================] - 0s 10ms/step - loss: 1.2287e-04 - val_loss: 1.1584e-04
# Epoch 33/80
# 16/16 [==============================] - 0s 10ms/step - loss: 1.1590e-04 - val_loss: 1.1119e-04
# Epoch 34/80
# Epoch 62/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.3640e-05 - val_loss: 6.6061e-05
# Epoch 63/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.5868e-05 - val_loss: 6.4429e-05
# Epoch 64/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.5450e-05 - val_loss: 6.3567e-05
# Epoch 65/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.2882e-05 - val_loss: 6.5872e-05
# Epoch 66/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.2598e-05 - val_loss: 6.1793e-05
# Epoch 67/80
# 16/16 [==============================] - 0s 11ms/step - loss: 6.0750e-05 - val_loss: 6.0254e-05
# Epoch 68/80
# 16/16 [==============================] - 0s 11ms/step - loss: 6.0933e-05 - val_loss: 6.1298e-05
# Epoch 69/80
# 16/16 [==============================] - 0s 11ms/step - loss: 6.0970e-05 - val_loss: 6.1721e-05
# Epoch 70/80
# 16/16 [==============================] - 0s 11ms/step - loss: 5.9061e-05 - val_loss: 5.8267e-05
# Epoch 71/80
# 16/16 [==============================] - 0s 10ms/step - loss: 6.0194e-05 - val_loss: 5.8808e-05
# Epoch 72/80
# 16/16 [==============================] - 0s 10ms/step - loss: 5.7540e-05 - val_loss: 5.6050e-05
# Epoch 73/80
# 16/16 [==============================] - 0s 11ms/step - loss: 5.5241e-05 - val_loss: 5.5629e-05
# Epoch 74/80
# 16/16 [==============================] - 0s 11ms/step - loss: 5.4312e-05 - val_loss: 5.3981e-05
# Epoch 75/80
# 16/16 [==============================] - 0s 11ms/step - loss: 6.0307e-05 - val_loss: 5.4171e-05
# Epoch 76/80
# 16/16 [==============================] - 0s 10ms/step - loss: 5.3803e-05 - val_loss: 5.5597e-05
# Epoch 77/80
# 16/16 [==============================] - 0s 10ms/step - loss: 5.3447e-05 - val_loss: 5.6983e-05
# Epoch 78/80
# 16/16 [==============================] - 0s 10ms/step - loss: 5.4380e-05 - val_loss: 5.3530e-05
# Epoch 79/80
# 16/16 [==============================] - 0s 11ms/step - loss: 5.1780e-05 - val_loss: 5.2953e-05
# Epoch 80/80
# 16/16 [==============================] - 0s 11ms/step - loss: 5.2872e-05 - val_loss: 4.9515e-05

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
